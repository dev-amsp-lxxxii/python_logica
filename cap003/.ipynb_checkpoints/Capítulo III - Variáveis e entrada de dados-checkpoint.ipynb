# %% [markdown]
# ### 3.2 - Variáveis numéricas

# %%
print(1_000)
print(1_000_000)
print(1_0_0)
print(1_980.10)
# Out:
# 1000
# 1000000
# 100
# 1980.1

# %%
# 531
print(5 * 10**2 + 3 * 10**1 + 1 * 10**0)
print(5 * 100 + 3 * 10 + 1 * 1)
print(500 + 30 + 1)
# Out:
# 531
# 531
# 531

# %%
# 1010 -> 10
print(1 * 2**3 + 0 * 2**2 + 1 * 2**1 + 0 * 2**0)
print(1 * 8 + 0 * 4 + 1 * 2 + 0 * 1)
print(8 + 0 + 2 + 0)
# Out:
# 10
# 10
# 10

# %%
# Para precisão procurar sobre decimal e fractions
3 * 0.1
# Out:
# 0.30000000000000004

# %%
a = 0b11 # base 2 - binário
b = 0x11 # base 16 - hexadecimal
c = 0o11 # base 8 - octal
print(f"a = 0b11 -> {a}")
print(f"b = 0x11 -> {b}")
print(f"c = 0o11 -> {c}")
# Out:
# a = 0b11 -> 3
# b = 0x11 -> 17
# c = 0o11 -> 9

# %% [markdown]
# ### 3.3 Variáveis do tipo Lógico

# %%
resultado = True
aprovado = False
print(f"resultado: {resultado} e aprovado: {aprovado}")
# Out:
# resultado: True e aprovado: False

# %%
# Operadores relacionais

# == igualdade
# >  maior que
# <  menor que
# != diferente
# >= maior ou igual que
# <= menor ou igual que

# %%
opr_a = 1
opr_b = 5
opr_c = 2
opr_d = 1

print(f"A é igual a B? {opr_a == opr_b}")
print(f"B é maior que A? {opr_b > opr_a}")
print(f"A é menor que B? {opr_a < opr_b}")
print(f"A é igual a D? {opr_a == opr_d}")
print(f"B é maior ou iguala a A? {opr_b >= opr_a}")
print(f"C é menor ou igual a B? {opr_c <= opr_b}")
print(f"D é diferente de A? {opr_d != opr_a}")
print(f"D é diferente de B? {opr_d != opr_b}")
# Out:
# A é igual a B? False
# B é maior que A? True
# A é menor que B? True
# A é igual a D? True
# B é maior ou iguala a A? True
# C é menor ou igual a B? True
# D é diferente de A? False
# D é diferente de B? True

# %%
nota = 8.0
media = 7.0
aprovado = nota >= media
print(f"Aprovado: {aprovado}")
# Out:
# Aprovado: True

# %%
# Exercício 3.2
"""
Complete a tabela a seguir, respondendo True ou False.
Considere  ex_a = 4, ex_b = 10, ex_c = 5.0, ex_d = 1 e ex_f = 5 
"""

ex_a = 4; ex_b = 10; ex_c = 5.0; ex_d = 1; ex_f = 5

print(f"a == c -> {ex_a} == {ex_c}: {ex_a == ex_c}")
print(f"a < b  -> {ex_a} < {ex_b}: {ex_a < ex_b}")
print(f"d > b  -> {ex_d} > {ex_b}: {ex_d > ex_b}")
print(f"c != f -> {ex_c} != {ex_f}: {ex_c != ex_f}")
print(f"a == b -> {ex_a} == {ex_b}: {ex_a == ex_b}")
print(f"c < d  -> {ex_c} < {ex_d}: {ex_c < ex_d}")
print(f"b > a  -> {ex_b} > {ex_a}: {ex_b > ex_a}")
print(f"c >= f -> {ex_c} >= {ex_f}: {ex_c >= ex_f}")
print(f"f >= c -> {ex_f} >= {ex_c}: {ex_c >= ex_f}")
print(f"c <= c -> {ex_c} <= {ex_c}: {ex_c <= ex_f}")
print(f"c <= f -> {ex_c} <= {ex_f}: {ex_c <= ex_c}")
# Out:
# a == c -> 4 == 5.0: False
# a < b  -> 4 < 10: True
# d > b  -> 1 > 10: False
# c != f -> 5.0 != 5: False
# a == b -> 4 == 10: False
# c < d  -> 5.0 < 1: False
# b > a  -> 10 > 4: True
# c >= f -> 5.0 >= 5: True
# f >= c -> 5 >= 5.0: True
# c <= c -> 5.0 <= 5.0: True
# c <= f -> 5.0 <= 5: True

# %%
# Operadores Lógicos

# not -> não (Operador unário)
# or -> ou (Operador binário)
# and -> e (Operador binário)

# %%
print(not True)
print(not False)
# Out:
# False
# True

# %%
print(True and True)
print(True and False)
print(False and True)
print(False and False)
# Out:
# True
# False
# False
# False

# %%
print(True or True)
print(True or False)
print(False or True)
print(False or False)
# Out:
# True
# True
# True
# False

# %%
# Exercício 3.3
"""
Complete a tabela a seguir utilizando a=True, b=False e c=True
"""

ol_a = True; ol_b = False; ol_c = True

print(f"a and a -> {ol_a} and {ol_a}: {ol_a and ol_a}")


print(f"b and b -> {ol_b} and {ol_b}: {ol_b and ol_b}")
print(f"not c   -> not {ol_c}: {not ol_c}")
print(f"not b   -> not {ol_b}: {not ol_b}")
print(f"not a   -> not {ol_a}: {not ol_a}")
print(f"a and b -> {ol_a} and {ol_b}: {ol_a and ol_b}")
print(f"b and c -> {ol_b} and {ol_c}: {ol_b and ol_c}")
print(f"a or c  -> {ol_a} or {ol_c}: {ol_a or ol_c}")
print(f"b or c  -> {ol_b} or {ol_c}: {ol_b or ol_c}")
print(f"c or a  -> {ol_c} or {ol_a}: {ol_c or ol_a}")
print(f"c or b  -> {ol_c} or {ol_b}: {ol_c or ol_b}")
print(f"c or c  -> {ol_c} or {ol_c}: {ol_c or ol_c}")
print(f"b or b  -> {ol_b} or {ol_b}: {ol_b or ol_b}")
# Out:
# a and a -> True and True: True
# b and b -> False and False: False
# not c   -> not True: False
# not b   -> not False: True
# not a   -> not True: False
# a and b -> True and False: False
# b and c -> False and True: False
# a or c  -> True or True: True
# b or c  -> False or True: True
# c or a  -> True or True: True
# c or b  -> True or False: True
# c or c  -> True or True: True
# b or b  -> False or False: False

# %%
# Expressões lógicas: 1° not; 2° and; 3° or

print(True or False and not True)
# Out:
# True

# %%
ol_salario = 900
ol_idade = 20

print(ol_salario > 1000 and ol_idade > 18)
print(100 > 1000 and 20 > 18)
(False and True)
# Out:
# False
# False
# False

# %%
ol_salario = 2_000
ol_idade = 30

print(ol_salario > 1000 and ol_idade > 18)
print(2_000 > 1_000 and 30 > 18)
(True and True)
# Out:
# True
# True
# True

# %%
# Exercício 3.4
"""
Escreva uma expressão para determinar se uma pessoa deve ou não pagar imposto.
Considere que pagam impostos pessoas cujo salário é maior que R$ 1.200,00
"""

ex_nome = "Adelmo Menezes"
ex_salario = 1_200.50

print(f"O Sr(a). {ex_nome} deve pagar imposto? {ex_salario > 1_200.00}")
# Out:
# O Sr(a). Adelmo Menezes deve pagar imposto? True

# %%
# Exercício 3.5
"""
Calcule o resultado da expressão A > B and C or D, utilizando os valores da 
tabela a seguir: 
A-B-C-D
1-2-True-False
10-3-False-False
5-1-True-True
"""

ex1_a = 1; ex1_b = 2; ex1_c = True; ex1_d = False
ex2_a = 10; ex2_b = 3; ex2_c = False; ex2_d = False
ex3_a = 5; ex3_b = 1; ex3_c = True; ex3_d = True

print(ex1_a > ex1_b and ex1_c or ex1_d)
print(ex2_a > ex2_b and ex2_c or ex2_d)
print(ex3_a > ex3_b and ex3_c or ex3_d)
# Out:
# False
# False
# True

# %%
# Exercício 3.6
"""
Escreva uma expressão que será utilizado para decidir se um aluno foi ou não aprovado.
Para ser aprovado, todas as médias do aluno devem ser maiores ou iguais a 7. Considere que o aluno
cursa apenas três matérias, e que a nota de cada uma está armazenada nas seguintes variáveis:
matéria01, matéria02, matéria03.
"""

nome = "Adelmo Menezes"

materia01 = 6.0;  materia02 = 7.5; materia03 = 9.5

resultado = (materia01 + materia02 + materia03) / 3

print(f"O aluno {nome} está aprovado? {resultado >= 7.0} com média: {resultado:.2f}")
# Out:
# O aluno Adelmo Menezes está aprovado? True com média: 7.67

# %% [markdown]
# ### 3.4 - Variáveis string

# %%
caracter = "João e Maria comem pão."
print(caracter)
len(caracter)
# Out:
# João e Maria comem pão.
# 23

# %%
print(len("A"))
print(len("AB"))
print(len(""))
print(len("O rato roeu a roupa."))
# Out:
# 1
# 2
# 0
# 20

# %%
acessar = "ABCDEFGHI"
print(len(acessar))
# Out:
# 9

# %%
print(acessar[0])
print(acessar[1])
print(acessar[5])
print(acessar[9])
# Out:
# A
# B
# F
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[8], line 4
#       2 print(acessar[1])
#       3 print(acessar[5])
# ----> 4 print(acessar[9])
#
# IndexError: string index out of range

# %%
# 3.4.1.1 - Concatenação
s = "ABC"
print(s + "C")
print(s + "D" * 4)
# Out:
# ABCC
# ABCDDDD

# %%
print("X" + "-" * 10 + "X")
imprimir = s + "x4 = " + s * 4
print(imprimir) # esse tipo de concatenação só pode ser usada com strings.
# Out:
# X----------X
# ABCx4 = ABCABCABCABC

# %%
# 3.4.1.2 - Composição
x_idade = 15
imprimir_idade = "João tem %d anos." % x_idade
print(imprimir_idade)

# principais marcadores -> %d inteiros - %s string - %f decimais
# Out:
# João tem 15 anos.

# %%
idade = 43
print("[%d]" % idade)
print("[%03d]" % idade)
print("[%3d]" % idade)
print("[%-3d]" % idade)
# Out:
# [43]
# [043]
# [ 43]
# [43 ]

# %%
print("R$%f" % 7)
print("R$%5f" % 7)
print("R$%5.2f" % 7)
print("R$%10.5f" % 7)
# Out:
# R$7.000000
# R$7.000000
# R$ 7.00
# R$   7.00000

# %%
composicao_nome = "Adelmo"
composicao_idade = 43
composicao_saldo = 51.34

# %%
# Marcador
print("%s tem %d anos e R$%f no bolso." % (composicao_nome, composicao_idade, composicao_saldo))
print("[%12s] tem [%3d] anos e [R$%5.2f] no bolso." % (composicao_nome, composicao_idade, composicao_saldo))
print("[%12s] tem [%03d] anos e [R$%5.2f] no bolso." % (composicao_nome, composicao_idade, composicao_saldo))
print("[%-12s] tem [%-3d] anos e [R$%-5.2f] no bolso." % (composicao_nome, composicao_idade, composicao_saldo))
# Out:
# [Adelmo] tem [43] anos e [R$51.340000] no bolso.
# [      Adelmo] tem [ 43] anos e [R$51.34] no bolso.
# [      Adelmo] tem [043] anos e [R$51.34] no bolso.
# [Adelmo      ] tem [43 ] anos e [R$51.34] no bolso.

# %%
# format()
print("{} tem {} anos e R${} no bolso.".format(composicao_nome, composicao_idade, composicao_saldo))
print("[{:12}] tem [{:3}] anos e [R${:5.2f}] no bolso.".format(composicao_nome, composicao_idade, composicao_saldo))
print("[{:12}] tem [{:03}] anos e [R${:5.2f}] no bolso.".format(composicao_nome, composicao_idade, composicao_saldo))
print("[{:<12s}] tem [{:<3}] anos e [R${:5.2f}] no bolso.".format(composicao_nome, composicao_idade, composicao_saldo))
# Out:
# Adelmo tem 43 anos e R$51.34 no bolso.
# [Adelmo      ] tem [ 43] anos e [R$51.34] no bolso.
# [Adelmo      ] tem [043] anos e [R$51.34] no bolso.
# [Adelmo      ] tem [43 ] anos e [R$51.34] no bolso.

# %%
print("{1} - {0} - {2}".format("A", "B", "C"))
print("{2} - {2} - {0} - {1}".format("A", "B", "C"))
# Out:
# B - A - C
# C - C - A - B

# %%
# f-string
print(f"{composicao_nome} tem {composicao_idade} anos e R${composicao_saldo} no bolso.")
print(f"[{composicao_nome:12}] tem [{composicao_idade:3}] anos e [R${composicao_saldo:5.2f}] no bolso.")
print(f"[{composicao_nome:12}] tem [{composicao_idade:03}] anos e [R${composicao_saldo:5.2f}] no bolso.")
print(f"[{composicao_nome:<12}] tem [{composicao_idade:<3}] anos e [R${composicao_saldo:5.2f}] no bolso.")
# Out:
# Adelmo tem 43 anos e R$51.34 no bolso.
# [Adelmo      ] tem [ 43] anos e [R$51.34] no bolso.
# [Adelmo      ] tem [043] anos e [R$51.34] no bolso.
# [Adelmo      ] tem [43 ] anos e [R$51.34] no bolso.

# %%
# fatiamento
fatia_s = "ABCDEFGHI"
print(fatia_s[0:2])
print(fatia_s[1:2])
print(fatia_s[2:4])
print(fatia_s[0:5])
print(fatia_s[1:8])
# Out:
# AB
# B
# CD
# ABCDE
# BCDEFGH

# %%
print(fatia_s[:2])
print(fatia_s[1:])
print(fatia_s[:])
# Out:
# AB
# BCDEFGHI
# ABCDEFGHI

# %%
print(fatia_s[0:-2])
print(fatia_s[-1:])
print(fatia_s[-5:7])
print(fatia_s[-2:-1])
# Out:
# ABCDEFG
# I
# EFG
# H

# %%
print(fatia_s[::-1])
print(fatia_s[::2])
# Out:
# IHGFEDCBA
# ACEGI

# %% [markdown]
# ### 3.5 - Sequências e tempo

# %%
# Programa 3.1 - Exemplo de sequência e tempo

divida = 0
compra = 100
divida = divida + compra

compra = 200
divida = divida + compra

compra = 300
divida = divida + compra

compra = 0
print(divida)
# Out:
# 600

# %% [markdown]
# ### 3.7 - Entrada de dados

# %%
x_input = input("Digite um número: ")
print(x_input)
# Out:
# Digite um número:  10
# 10

# %%
nome_input = input("Digite seu nome: ")
print(f"Você digitou {nome_input}.")
print(f"Olá, {nome_input}!")
# Out:
# Digite seu nome:  Adelmo Menezes
# Você digitou Adelmo Menezes.
# Olá, Adelmo Menezes!

# %% [markdown]
# ###### 3.7.1 - Conversão de entrada de dados

# %%
anos = int(input("Anos de serviço: "))
valor_por_ano = float(input("Valor por ano: "))
bonus = anos * valor_por_ano
print(f"Bônus de R$ {bonus:5.2f}")
# Out:
# Anos de serviço:  10
# Valor por ano:  25
# Bônus de R$ 250.00

# %%
# Exercício 3.7
"""
Faça um programa que peça dois números inteiros.
Imprima a soma desses dois números na tela.
"""

int_a = int(input("Digite o valor a: "))
int_b = int(input("Digite o valor b: "))

adicao = int_a + int_b

print(f"{int_a} + {int_b} = {adicao}")
# Out:
# Digite o valor a:  10
# Digite o valor b:  15
# 10 + 15 = 25

# %%
# Exercício 3.8
"""
Escreva um programa que leia um valor em metros e o exiba
convertido em milímetros.
"""
float_metros = float(input("Informe a metragem: "))
converte_m_mm = float_metros * 1000
print(f"Metros: {float_metros} convertido para Milímetros: {converte_m_mm}")
# Out:
# Informe a metragem:  2
# Metros: 2.0 convertido para Milímetros: 2000.0

# %%
# Exercício 3.9
"""
Escreva um programa que leia a quantidade de dias, horas, minutos e segundos do usuário.
Calcule o total em segundos.
"""
int_dias = int(input("Informe o número de dias: "))
int_horas = int(input("Informe o número de horas: "))
int_min = int(input("Informe o número de minutos: "))
int_seg = int(input("Informe o número de segundos: "))

converte_dias = int_dias * 24 * 60 * 60 
converte_horas = int_horas * 60 * 60
converte_min = int_min * 60

resultado_conversao = converte_dias + converte_horas + converte_dias + int_seg 

print(f"{resultado_conversao} segundos")
# Out:
# Informe o número de dias:  1
# Informe o número de horas:  24
# Informe o número de minutos:  60
# Informe o número de segundos:  2
# 259202 segundos

# %%
# Exercício 3.10
"""
Faça um programa que calcule o aumento de um salário.
Ele deve solicitar o valor do salário e a porcentagem do aumento.
Exiba o valor do aumento e do novo salário.
"""

valor_salario = float(input("Informe o salário atual: "))
porcentagem_aumento = float(input("Informe o aumento em %: "))

calculo_porcentagem = (porcentagem_aumento / 100) * valor_salario
salario_atualizado = calculo_porcentagem + valor_salario

print(f"O salário defasado para: R$ {valor_salario:5.2f}")
print(f"Valor do aumento é R$ {calculo_porcentagem:5.2f}")
print(f"O salário atualizado para: R$ {salario_atualizado:5.2f}")
# Out:
# Informe o salário atual:  1000
# Informe o aumento em %:  15
# O salário defasado para: R$ 1000.00
# Valor do aumento é R$ 150.00
# O salário atualizado para: R$ 1150.00

# %%
# Exercício 3.11
"""
Faça um programa que solicite o preço de uma mercadoria e o
percentual de desconto. Exiba o valor de desconto e o preço a pagar.
"""

valor_mercadoria = float(input("Informe o valor do produto: "))
percentual_desconto = float(input("Informe o percentual do desconto: "))

calcular_percentual = (percentual_desconto / 100) * valor_mercadoria
valor_final = valor_mercadoria - calcular_percentual

print(f"Valor do produto R$ {valor_mercadoria:5.2f}")
print(f"Valor a ser descontado R$ {calcular_percentual:5.2f}")
print(f"Valor final a ser pago R$ {valor_final:5.2f}")
# Out:
# Informe o valor do produto:  1000
# Informe o percentual do desconto:  15
# Valor do produto R$ 1000.00
# Valor a ser descontado R$ 150.00
# Valor final a ser pago R$ 850.00

# %%
# Exercício 3.12
"""
Escreva um programa que calcule o tempo de uma viagem de carro.
Pergunte a distância a percorrer e a velocidade média esperada para a viagem.
"""

distancia = float(input("Qual a distância do percurso? "))
velocidade_media = float(input("Qual a velocidade média? "))

tempo = distancia / velocidade_media

print(f"Tempo de viagem será de {tempo}")
# Out:
# Qual a distância do percurso?  300
# Qual a velocidade média?  100
# Tempo de viagem será de 3.0

# %%
# Exercício 3.13
"""
Escreva um programa que converte uma temperatura digitada em 'C em F'.
A fórmula para essa conversão é: 
"""

celsus = int(input("Informe a temperatura em celsius: "))

f = ((9 * celsus) / 5) + 32

print(f"Celsius -> {celsus}°C")
print(f"{celsus}°C para {int(f)}°F")
# Out:
# Informe a temperatura em celsius:  30
# Celsius -> 30°C
# 30°C para 86°F

# %%
# Exercício 3.14
"""
Escreva um programa que pergunte a quantidade de km percorrido por um carro alugado
pelo usuário, assim como a quantidade de dias pelos quais o carro foi alugado. 
Calcule o preço a pagar, sabendo que o carro custa R$ 60 por dia e R$ 0.15 km rodado.
"""

dias_aluguel = int(input("Quantos dias o carro foi alugado? "))
km_rados = int(input("Quanto quilometros rodados? "))

total_a_pagar = (dias_aluguel * 60) + (km_rados * 0.15)

print(f"Dias alugados: {dias_aluguel} e Km rodados: {km_rados}")
print(f"Total a ser pago -> R$ {total_a_pagar:5.2f}")
# Out:
# Quantos dias o carro foi alugado?  2
# Quanto quilometros rodados?  175
# Dias alugados: 2 e Km rodados: 175
# Total a ser pago -> R$ 146.25

# %%
# Exercício 3.15
"""
Escreva um programa para calcular a redução do tempo de vida de um fumante.
Pergunte a quantidade de cigarros fumados por dia e quantos anos ele já fumou.
Considere que um fumante perde 10 min de vida a cada cigarro, e calcule quantos dias
de vida um fumante perderá.
Exiba o total em dias.
"""

cigarros_diarios = int(input("Quantos cigarros por dia: "))
anos_fumando = int(input("Quantos anos fumou: "))

qtd_cigarros = (anos_fumando * 365) * cigarros_diarios
tempo_min = qtd_cigarros * 10
dias_vida_perdida = float(tempo_min / 60 / 24)

print(f"dias perdidos de sua vida: {dias_vida_perdida:5.2f}")
# Out:
# Quantos cigarros por dia:  8
# Quantos anos fumou:  6
# dias perdidos de sua vida: 121.67
